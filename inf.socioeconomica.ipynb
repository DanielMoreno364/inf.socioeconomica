# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import geopandas as gpd

# %%
data=gpd.read_file('C:/Users/User/Desktop/archivosRSML/manzanaestratificacion/ManzanaEstratificacion.shp')
data.head()
# Out:
#   CODIGO_MAN  ESTRATO  CODIGO_ZON CODIGO_CRI NORMATIVA ACTO_ADMIN  NUMERO_ACT  \
# 0   00913633        0          20        394    DEC394        DEC         394
# 1   108101A1        6          17        394    DEC394        DEC         394
# 2   00913634        0          19        394    DEC394        DEC         394
# 3   00913626        6          17        394    DEC394        DEC         394
# 4   00853903        0          19        394    DEC394        DEC         394
#
#    FECHA_ACTO ESCALA_CAP  FECHA_CAPT RESPONSABL   SHAPE_Leng     SHAPE_Area  \
# 0  2017-07-28       None  2017-07-28        560  2203.905471  267773.513997
# 1  2017-07-28       None  2017-07-28        560  6350.896563  889000.149632
# 2  2017-07-28       None  2017-07-28        560  1488.773919  100924.112922
# 3  2017-07-28       None  2017-07-28        560   745.327665   33775.855324
# 4  2017-07-28       None  2017-07-28        560  1122.296445   70820.836179
#
# ...

# %%
data.plot('ESTRATO',legend=True, figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
data.plot('CODIGO_ZON',legend=True, figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
#data1=gpd.read_file('C:/Users/User/Desktop/archivosRSML/suelos.zip')
#data1.head()

# %%
#data1.plot('SueCodigo',legend=True,figsize=(15,10) )

# %%
#data3=gpd.read_file('C:/Users/User/Desktop/archivosRSML/upla.zip')
#data3.head()

# %%
#data3.plot('UPlCodigo',legend=False,figsize=(15,10))

# %%
data4=gpd.read_file('C:/Users/User/Desktop/archivosRSML/upz.gpkg')
data4.head()
# Out:
#   CODIGO_UPZ         NOMBRE ZONA_ESTACIONAMIENTO DECRETO_POT  \
# 0         16  SANTA BARBARA                    A         619
# 1         31  SANTA CECILIA                    V         190
# 2         19       EL PRADO                    C         619
# 3         32       SAN BLAS                    D         190
# 4         33        SOSIEGO                    D         190
#
#                                  ACTO_ADMINISTRATIVO  AREA_HECTAREAS  \
# 0                                    Dec 443 de 2011      458.698321
# 1  Dec 152 de 2006 Mod.=Res 320 de 2008, Dec 037 ...      308.579768
# 2  Dec 299 de 2002 Mod.=Res 820 de 2007, 1673 de ...      433.403358
# 3                                    Dec 378 de 2006      400.032232
# 4                                    Dec 382 de 2004      234.916345
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.03288 4.70341, -74.03594 4...
# 1  MULTIPOLYGON (((-74.09942 4.68105, -74.09945 4...
# ...

# %%
data4.plot('ZONA_ESTACIONAMIENTO',legend=True,figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
data5=gpd.read_file('C:/Users/User/Desktop/archivosRSML/ingresomensualdelosocupados.zip')
data5.head()
# Out:
#    LocCodigo  LocNombre       ipo2011       ipo2014       ipo2017  SHAPE_Leng  \
# 0         15         15  7.096233e+05  8.907229e+05  9.017007e+05    0.108973
# 1          6          6  5.427899e+05  6.921486e+05  7.881222e+05    0.210542
# 2         18         18  4.626603e+05  6.014510e+05  7.601530e+05    0.174513
# 3         20         20  0.000000e+00  0.000000e+00  4.023523e+05    1.914949
# 4          1          1  1.901147e+06  1.933692e+06  1.974102e+06    0.436907
#
#    SHAPE_Area                                           geometry
# 0    0.000397  POLYGON ((-74.13075 4.59335, -74.12917 4.59327...
# 1    0.000807  POLYGON ((-74.13777 4.59489, -74.13165 4.59363...
# 2    0.001126  POLYGON ((-74.12803 4.59254, -74.12777 4.59233...
# 3    0.063549  POLYGON ((-74.20584 4.26966, -74.20569 4.27048...
# 4    0.005310  POLYGON ((-74.01116 4.66459, -74.01117 4.66460...

# %%
data5.plot('ipo2017',legend=True,figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
data6=gpd.read_file('C:/Users/User/Desktop/archivosRSML/barrios/barrios.zip')
data6.head()
# Out:
#    OBJECTID CODIGO_LOC  CODIGO_UPZ CODIGO_BAR  \
# 0      1202         08           0       None
# 1      1203         13           0       None
# 2      1204         02           0       None
# 3      1205         02           0       None
# 4      1206         02           0       None
#
#                                NOMBRE SECTOR ESTADO_BAR ORIGEN_ILE  LINK  \
# 0  URBANIZACION SAN  JUAN DE CASTILLA   None       None       None  None
# 1               MINISTERIO DE DEFENSA   None       None       None  None
# 2                      MARIA CRISTINA   None       None       None  None
# 3         CONJUNTO RESIDENCIAL CERROS   None       None       None  None
# 4                   ALTOS DE LA SALLE   None       None       None  None
#
#   SIMBOLO ESCALA_CAP FECHA_CAPT   SHAPE_Leng     SHAPE_Area  \
# 0    None       None       None   855.038371   23884.595500
# 1    None       None       None  1384.895978  100492.234197
# 2    None       None       None   472.371358   12745.373158
# ...

# %%
data6.plot('NOMBRE',figsize=(20,12))
# Out:
# <AxesSubplot:>

# %%
#data7=gpd.read_file('C:/Users/User/Desktop/archivosRSML/densidadpoblacion/Grilla_id.geojson')
#data7.head()

# %%
#data7.plot('ID',legend=True,figsize=(15,10))

# %%
data8=gpd.read_file('C:/Users/User/Desktop/archivosRSML/densidadpoblacion/Centroides_Manzanas.geojson')
data8.head()
# Out:
#   CODIGO_MAN ESTRATO  CODIGO_ZON CODIGO_CRI NORMATIVA  FECHA_ACTO  NUMERO_ACT  \
# 0   00921249       2           9        544    DEC544  2009-12-17         544
# 1   00921248       2           5        544    DEC544  2009-12-17         544
# 2   00840722       6          17        544    DEC544  2009-12-17         544
# 3   006404A1       0          19        544    DEC544  2009-12-17         544
# 4   00652201       0          10        544    DEC544  2009-12-17         544
#
#   SIMBOLO ESCALA_CAP  FECHA_CAPT   SHAPE_Leng  LINK  VIV_2010  PER_S010  \
# 0    None       5000  2009-12-17   322.936425  None      27.0     108.0
# 1    None       5000  2009-12-17   175.602230  None       6.0      24.0
# 2    None       5000  2009-12-17   858.663177  None      79.0     270.0
# 3    None       5000  2009-12-17   327.777988  None       0.0       0.0
# 4    None       5000  2009-12-17  1751.712026  None       0.0       0.0
#
# ...

# %%
data8.plot(column='DENSIDAD_P', scheme='QUANTILES', k=3,legend=True,figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
data9=gpd.read_file('C:/Users/User/Desktop/archivosRSML/centros comerciales/cco.geojson')
data9.head()
# Out:
#                                        CCENNOM  \
# 0   Pasaje Cultural y Comercial CED Centenario
# 1  Caseta Feria Popular Rotonda Barrios Unidos
# 2              Punto Comercial Siete de agosto
# 3                 Plataforma Logística de Bosa
# 4                    Centro Comercial Caravana
#
#                            CCENDIR         CCENLOC  \
# 0  Transversal 21 A # 21A - 65 Sur  Antonio Nariño
# 1             Calle 72 A # 67 - 75  Barrios Unidos
# 2             Carrera 25 # 66 - 65  Barrios Unidos
# 3             Calle 69 SUR # 95-56            Bosa
# 4                Calle 12 # 9 - 68      Candelaria
#
#                                CCENBARRIO  \
# 0  Restrepo - U.R. Alfonso Lopez Pumarejo
# 1                            San Fernando
# 2                         Siete De Agosto
# 3                 S.C. San Bernardino Xvi
# 4                             La Catedral
#
#                                              CCENHOR  \
# ...

# %%
data10=gpd.read_file('C:/Users/User/Desktop/archivosRSML/area_urb.json')
data10.head()
# Out:
#    OBJECTID   AUrCodigo                          AUrAAdmini  AUrTPlano  \
# 0    102267  112397B001    Resolución  14-2-0546  7/04/2014          1
# 1    102268  111572B002   Resolución  14-4-0486  13/03/2014          1
# 2    102269  112780B001  Resolución  13-3-1071   18/12/2013          1
# 3    102270  112074B004   Resolución  16-5-1180  13/07/2016          1
# 4    102271  040352B002   Resolución  16-3-1364  15/09/2016          6
#
#       AUrCPlano        AUrArea  \
# 0   CU2S29/4-00    4833.125366
# 1   CU4S22/4-05    5354.582541
# 2  CU3S100/4-37  211618.722197
# 3  CU5S373/4-02    1992.599194
# 4  CU3SC35/4-01   38044.437640
#
#                                            AUrNombre  SHAPE_Length  \
# 0                   NIZA SUBA CARRERA 78A No. 131-58      0.003085
# 1                           URBANIZACIÓN COLINA 129.      0.002669
# 2                           URBANIZACIÓN CASA BLANCA      0.022947
# 3  PROYECTO URBANISTICO MODALIDAD DE SANEAMIENTO ...      0.001730
# ...

# %%
data10.plot('OBJECTID',figsize=(15,10), legend= True)
# Out:
# <AxesSubplot:>

# %%
data11=gpd.read_file('C:/Users/User/Desktop/archivosRSML/Calzada.geojson')
data11.head()
# Out:
#    CalFuncion  CalTSuperf  CalCodigo    CalCIV  CalAncho  CalLongitu  \
# 0           1           1     450774  19005215      5.44       23.57
# 1           1           2     322232   6000769      5.86       51.02
# 2           1           1     204411   4001628      5.65       36.21
# 3           1           2     387502   9002983      5.59      109.18
# 4           1           2     358851   7003415      2.83       37.88
#
#    SHAPE_Length    SHAPE_Area  \
# 0      0.000653  1.043383e-08
# 1      0.001026  2.435026e-08
# 2      0.000752  1.665462e-08
# 3      0.002161  4.973400e-08
# 4      0.000806  8.718553e-09
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.15103 4.56902, -74.15113 4...
# 1  MULTIPOLYGON (((-74.13202 4.58474, -74.13207 4...
# 2  MULTIPOLYGON (((-74.08316 4.56439, -74.08319 4...
# 3  MULTIPOLYGON (((-74.11815 4.66902, -74.11816 4...
# 4  MULTIPOLYGON (((-74.18383 4.61981, -74.18382 4...

# %%
data11.plot(figsize=(30,20),color='red')
# Out:
# <AxesSubplot:>

# %%
data12=gpd.read_file('C:/Users/User/Desktop/archivosRSML/Ciclorruta.geojson')
data12.head()
# Out:
#    CicTSuperf  CicCodigo    CicCIV  SHAPE_Length    SHAPE_Area  \
# 0           2   34013476   7009283      0.000129  9.796155e-10
# 1           2   35003098  12002289      0.001693  2.300766e-08
# 2           4   35003046  13001032      0.002548  3.222010e-08
# 3           2   35003047  10010469      0.003033  2.232427e-08
# 4           2   35003096  12002289      0.000248  2.611396e-09
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.19298 4.61537, -74.19301 4...
# 1  MULTIPOLYGON (((-74.08599 4.66560, -74.08600 4...
# 2  MULTIPOLYGON (((-74.07214 4.64153, -74.07224 4...
# 3  MULTIPOLYGON (((-74.14335 4.71964, -74.14332 4...
# 4  MULTIPOLYGON (((-74.08665 4.66441, -74.08668 4...

# %%
data12.plot(figsize=(30,20),color='red')
# Out:
# <AxesSubplot:>

# %%
data13=gpd.read_file('C:/Users/User/Desktop/archivosRSML/Anden.geojson')
data13.head()
# Out:
#    AndMateria  AndCodigo    AndCIV  SHAPE_Length    SHAPE_Area  \
# 0           1     385799   9002234      0.002257  2.437835e-08
# 1           1      59051  11001791      0.001284  8.495042e-09
# 2           1      11950   3001944      0.000621  3.723114e-09
# 3           1      69921  14001599      0.001323  2.330967e-08
# 4           1      33521  10009001      0.001733  2.418141e-08
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.12076 4.67481, -74.12078 4...
# 1  MULTIPOLYGON (((-74.11601 4.75251, -74.11601 4...
# 2  MULTIPOLYGON (((-74.07693 4.57926, -74.07693 4...
# 3  MULTIPOLYGON (((-74.09064 4.59492, -74.09066 4...
# 4  MULTIPOLYGON (((-74.10797 4.67666, -74.10797 4...

# %%
data13.plot(figsize=(30,20),color='red')
# Out:
# <AxesSubplot:>

# %%
data14=gpd.read_file('C:/Users/User/Desktop/archivosRSML/mapa_referencia.zip')
data14.head()
# Out:
#    AITIdentif  AITFuente   AITArea            AITUbicaci  AITTransit  \
# 0          10          1  1.509998  AC 75 sur No. 81 -21           0
# 1          16          1  1.925099       AC 183 No. 7-40           1
# 2          22          1  1.960543       AC 170 No. 7–60           0
# 3          34          1  2.588754       Kr 96 No. 72-30           0
# 4          50          1  1.283960      Cl 144 No.139-55           0
#
#    AITZSitp  AITEstado  SHAPE_Leng  SHAPE_Area  \
# 0         9          1    0.004529    0.000001
# 1         1          1    0.006921    0.000002
# 2         1          1    0.009275    0.000002
# 3         4          1    0.008147    0.000002
# 4         3          1    0.004192    0.000001
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.20585 4.61296, -74.20582 4...
# 1  MULTIPOLYGON (((-74.02833 4.76218, -74.02832 4...
# 2  MULTIPOLYGON (((-74.02756 4.74838, -74.02336 4...
# ...

# %%
data14.plot('AITIdentif',figsize=(30,20))
# Out:
# <AxesSubplot:>

# %%
data15=gpd.read_file('C:/Users/User/Desktop/archivosRSML/Siniestros_Viales_Bogota_Accidente.geojson')
data15.head()
# Out:
#    OBJECTID  FORMULARIO  CODIGO_ACCIDENTE HORA_OCURRENCIA_ACC  \
# 0         1  A001232786          10533629            13:30:00
# 1         2       A8472           4416604            08:40:00
# 2         3  A000555209           4472710            11:58:00
# 3         4  A000402412           4448666            16:00:00
# 4         5  A000551938           4468964            20:00:00
#
#    ANO_OCURRENCIA_ACC MES_OCURRENCIA_ACC DIA_OCURRENCIA_ACC    GRAVEDAD  \
# 0                2020          NOVIEMBRE             MARTES  SOLO DANOS
# 1                2015              JUNIO             JUEVES  SOLO DANOS
# 2                2017            FEBRERO             SABADO  SOLO DANOS
# 3                2016              JUNIO             JUEVES  SOLO DANOS
# 4                2016          DICIEMBRE            VIERNES  SOLO DANOS
#
#   CLASE_ACC  LOCALIDAD       FECHA_HORA_ACC   LATITUD   LONGITUD         CIV  \
# 0    CHOQUE    USAQUEN  2020-11-10T13:30:00  4.682000 -74.042000  30001107.0
# ...

# %%
data15.plot( figsize=(20,20), legend=True)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(6,20))
sns.kdeplot(data=data15,y='LATITUD', x='LONGITUD', fill=True, cmap='coolwarm',alpha=0.3, gridsize=200, levels=20, ax=ax)
# Out:
# <AxesSubplot:xlabel='LONGITUD', ylabel='LATITUD'>

# %% [markdown]
# # SOLO DAÑOS

# %%
data151=data15[data15.GRAVEDAD=='SOLO DANOS']
data151.head()
# Out:
#    OBJECTID  FORMULARIO  CODIGO_ACCIDENTE HORA_OCURRENCIA_ACC  \
# 0         1  A001232786          10533629            13:30:00
# 1         2       A8472           4416604            08:40:00
# 2         3  A000555209           4472710            11:58:00
# 3         4  A000402412           4448666            16:00:00
# 4         5  A000551938           4468964            20:00:00
#
#    ANO_OCURRENCIA_ACC MES_OCURRENCIA_ACC DIA_OCURRENCIA_ACC    GRAVEDAD  \
# 0                2020          NOVIEMBRE             MARTES  SOLO DANOS
# 1                2015              JUNIO             JUEVES  SOLO DANOS
# 2                2017            FEBRERO             SABADO  SOLO DANOS
# 3                2016              JUNIO             JUEVES  SOLO DANOS
# 4                2016          DICIEMBRE            VIERNES  SOLO DANOS
#
#   CLASE_ACC  LOCALIDAD       FECHA_HORA_ACC   LATITUD   LONGITUD         CIV  \
# 0    CHOQUE    USAQUEN  2020-11-10T13:30:00  4.682000 -74.042000  30001107.0
# ...

# %%
data151.describe()
# Out:
#             OBJECTID  CODIGO_ACCIDENTE  ANO_OCURRENCIA_ACC        LATITUD  \
# count  141721.000000      1.417210e+05       141721.000000  141721.000000
# mean   107896.986925      7.573833e+06         2018.065502       4.654872
# std     63895.636069      3.023686e+06            2.073326       0.055929
# min         1.000000      4.401420e+06         2015.000000       4.122000
# 25%     52436.000000      4.463319e+06         2016.000000       4.615232
# 50%    106689.000000      1.045033e+07         2018.000000       4.653840
# 75%    162545.000000      1.051134e+07         2020.000000       4.694000
# max    221906.000000      1.057258e+07         2022.000000       4.828041
#
#             LONGITUD           CIV    PK_CALZADA
# count  141721.000000  1.404650e+05  1.051480e+05
# mean      -74.100118  1.377051e+07  7.909680e+06
# std         0.039465  1.370798e+07  1.870332e+07
# min       -74.217000  0.000000e+00  0.000000e+00
# 25%       -74.128731  7.003588e+06  4.098700e+04
# ...

# %%
data151.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(6,20))
sns.kdeplot(data=data151,y='LATITUD', x='LONGITUD', fill=True, cmap='coolwarm',alpha=0.3, gridsize=200, levels=20, ax=ax)
# Out:
# <AxesSubplot:xlabel='LONGITUD', ylabel='LATITUD'>

# %% [markdown]
# # CON HERIDOS

# %%
data152=data15[data15.GRAVEDAD=='CON HERIDOS']
data152.head()
# Out:
#     OBJECTID  FORMULARIO  CODIGO_ACCIDENTE HORA_OCURRENCIA_ACC  \
# 5          6  A000761324           4510438            23:10:00
# 8          9  A001392643          10563307            10:22:00
# 15        16  A000818881          10451506            12:40:00
# 22        23  A000819848          10451958            19:40:00
# 30        31  A000819230          10451671            06:10:00
#
#     ANO_OCURRENCIA_ACC MES_OCURRENCIA_ACC DIA_OCURRENCIA_ACC     GRAVEDAD  \
# 5                 2018              MARZO              LUNES  CON HERIDOS
# 8                 2022            FEBRERO             MARTES  CON HERIDOS
# 15                2018              JUNIO              LUNES  CON HERIDOS
# 22                2018              JUNIO            VIERNES  CON HERIDOS
# 30                2018              JUNIO          MIERCOLES  CON HERIDOS
#
#     CLASE_ACC       LOCALIDAD       FECHA_HORA_ACC   LATITUD   LONGITUD  \
# ...

# %%
data152.describe()
# Out:
#             OBJECTID  CODIGO_ACCIDENTE  ANO_OCURRENCIA_ACC       LATITUD  \
# count   76588.000000      7.658800e+04        76588.000000  76588.000000
# mean   116518.428892      7.925775e+06         2018.299224      4.638548
# std     64023.165503      2.995088e+06            2.145417      0.058773
# min         6.000000      4.401421e+06         2015.000000      4.387000
# 25%     61291.500000      4.467671e+06         2016.000000      4.597627
# 50%    118445.500000      1.046450e+07         2018.000000      4.630183
# 75%    172877.500000      1.051947e+07         2020.000000      4.682045
# max    221909.000000      1.057273e+07         2022.000000      4.821924
#
#            LONGITUD           CIV    PK_CALZADA
# count  76588.000000  7.604000e+04  5.349100e+04
# mean     -74.111843  1.374595e+07  6.941733e+06
# std        0.040024  1.286187e+07  1.779211e+07
# min      -74.224452  0.000000e+00  0.000000e+00
# 25%      -74.140471  7.005791e+06  5.540800e+04
# ...

# %%
data152.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(6,20))
sns.kdeplot(data=data152,y='LATITUD', x='LONGITUD', fill=True, cmap='coolwarm',alpha=0.3, gridsize=200, levels=20, ax=ax)
# Out:
# <AxesSubplot:xlabel='LONGITUD', ylabel='LATITUD'>

# %% [markdown]
# # CON MUERTOS

# %%
data153=data15[data15.GRAVEDAD=='CON MUERTOS']
data153.head()
# Out:
#      OBJECTID  FORMULARIO  CODIGO_ACCIDENTE HORA_OCURRENCIA_ACC  \
# 48         49  A000872774          10461326            23:20:00
# 64         65  A000819691          10452006            21:05:00
# 162       163  A000874161          10463253            09:50:00
# 512       513  A000237693           4423828            12:16:00
# 628       629  A000648127           4490948            20:30:00
#
#      ANO_OCURRENCIA_ACC MES_OCURRENCIA_ACC DIA_OCURRENCIA_ACC     GRAVEDAD  \
# 48                 2018         SEPTIEMBRE            VIERNES  CON MUERTOS
# 64                 2018              JUNIO            VIERNES  CON MUERTOS
# 162                2018            OCTUBRE          MIERCOLES  CON MUERTOS
# 512                2015         SEPTIEMBRE          MIERCOLES  CON MUERTOS
# 628                2017             AGOSTO             JUEVES  CON MUERTOS
#
#        CLASE_ACC       LOCALIDAD       FECHA_HORA_ACC   LATITUD   LONGITUD  \
# ...

# %%
data153.describe()
# Out:
#             OBJECTID  CODIGO_ACCIDENTE  ANO_OCURRENCIA_ACC      LATITUD  \
# count    3600.000000      3.600000e+03         3600.000000  3600.000000
# mean   112980.771944      7.599661e+06         2018.092222     4.631472
# std     63258.016162      3.025609e+06            2.144112     0.062928
# min        49.000000      4.401613e+06         2015.000000     4.085800
# 25%     60066.000000      4.459852e+06         2016.000000     4.590927
# 50%    110408.000000      1.045109e+07         2018.000000     4.623771
# 75%    171388.750000      1.051680e+07         2020.000000     4.676207
# max    221873.000000      1.057203e+07         2022.000000     4.821000
#
#           LONGITUD           CIV    PK_CALZADA
# count  3600.000000  3.577000e+03  2.533000e+03
# mean    -74.114745  1.438481e+07  7.925448e+06
# std       0.038566  1.336368e+07  1.853541e+07
# min     -74.228300  0.000000e+00  0.000000e+00
# 25%     -74.141701  7.005543e+06  6.147900e+04
# ...

# %%
data153.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(6,20))
sns.kdeplot(data=data153,y='LATITUD', x='LONGITUD', fill=True, cmap='coolwarm',alpha=0.3, gridsize=200, levels=20, ax=ax)
# Out:
# <AxesSubplot:xlabel='LONGITUD', ylabel='LATITUD'>

# %%
sns.kdeplot(data=data153,y='LATITUD', x='LONGITUD', fill=True, cmap='coolwarm',alpha=0.3, gridsize=200, levels=40, legend=True)
# Out:
# <AxesSubplot:xlabel='LONGITUD', ylabel='LATITUD'>

# %%
data16=gpd.read_file('C:/Users/User/Desktop/archivosRSML/luminarias_upz.zip')
data16.head()

# %%
data16.plot('LED')
